# %% [markdown]
# # Storytelling Challenge
#
# The goal was to understand why people who got the vaccine have chosen to not get the booster, especially with the booster now being widely availble.
#
# Through analyzing different maps and graphs I was able to come to the conclusion that the main reasons are dislike for the booster and laziness in getting the booster.

# %% [markdown]
# ### Importing

# %%
import pandas as pd
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
pulse = pd.read_csv("pulse2022_puf_46.csv")

# %% [markdown]
# ### Cleaning Data For Maps
#
# Each map required two steps
# * First step was retrieving the data for each state from the original dataframe
# * Second step was matching the states with their abbrevations to function with the geoJSON file

# %%
i = 1
vacc_state = {}
invalid = [3, 7, 11, 14, 43, 52]

while(i < 57):
    if(i not in invalid):
        j = 0
        didr = 0
        notr = 0
        cur_state = pulse[(pulse['EST_ST']==i)]
        cur_state.reset_index(inplace = True)
        while(j < len(cur_state)):
            if(cur_state.loc[j, "RECVDVACC"] == 1):
                didr += 1
            elif(cur_state.loc[j, "RECVDVACC"] == 2):
                notr += 1
            j += 1
        percent = didr / (didr + notr)
        vacc_state[i] = percent
    i += 1

######################################################################################    

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

i = 1
state = 0
invalid = [3, 7, 11, 14, 43, 52]
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", 
          "FL", "GA", "HI", "ID", "IL", "IN", "IA", 
          "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", 
          "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", 
          "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", 
          "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", 
          "WV", "WI", "WY"]
data = {'State': [], 'Percent': []}
vacc_data = pd.DataFrame(data=data)
while(i < 57):
    if(i not in invalid):
        cur_per = vacc_state.get(i)
        vacc_data = vacc_data.append({'State': states[state], 'Percent': cur_per}, ignore_index=True)
        state += 1
    i += 1

# %%
i = 1
boost_state = {}
invalid = [3, 7, 11, 14, 43, 52]

while(i < 57):
    if(i not in invalid):
        j = 0
        didu = 0
        notu = 0
        cur_state = pulse[(pulse['EST_ST']==i)]
        cur_state.reset_index(inplace = True)
        while(j < len(cur_state)):
            if(cur_state.loc[j, "BOOSTERRV"] == 1):
                didu += 1
            elif(cur_state.loc[j, "BOOSTERRV"] == 2):
                notu += 1
            j += 1
        percent = didu / (didu + notu)
        boost_state[i] = percent
    i += 1

###################################################################################### 

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

i = 1
state = 0
invalid = [3, 7, 11, 14, 43, 52]
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", 
          "FL", "GA", "HI", "ID", "IL", "IN", "IA", 
          "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", 
          "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", 
          "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", 
          "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", 
          "WV", "WI", "WY"]
data = {'State': [], 'Percent': []}
boost_data = pd.DataFrame(data=data)
while(i < 57):
    if(i not in invalid):
        cur_per = boost_state.get(i)
        boost_data = boost_data.append({'State': states[state], 'Percent': cur_per}, ignore_index=True)
        state += 1
    i += 1

# %%
i = 0
noboost = []

while(i < 50):
    vacc = vacc_data.loc[i, "Percent"]
    boost = boost_data.loc[i, "Percent"]
    noboost.append(vacc - boost)
    i += 1

######################################################################################    

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

i = 0
state = 0
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", 
          "FL", "GA", "HI", "ID", "IL", "IN", "IA", 
          "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", 
          "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", 
          "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", 
          "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", 
          "WV", "WI", "WY"]
data = {'State': [], 'Percent': []}
noboost_data = pd.DataFrame(data=data)
while(i < 50):
    cur_per = noboost[i]
    noboost_data = noboost_data.append({'State': states[state], 'Percent': cur_per}, ignore_index=True)
    state += 1
    i += 1

# %% [markdown]
# ### Creating Maps
#
# * Utilized geoJSON provided from Folium github

# %%
state_geo = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json'

map1 = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=vacc_data,
    columns=['State', 'Percent'],
    key_on='feature.id',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Vaccination Rate (%)'
).add_to(map1)

map2 = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=boost_data,
    columns=['State', 'Percent'],
    key_on='feature.id',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Booster Rate (%)'
).add_to(map2)

map3 = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=noboost_data,
    columns=['State', 'Percent'],
    key_on='feature.id',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Vaccination/Booster Difference (Difference of %)'
).add_to(map3)

# %% [markdown]
# ### Displaying Maps

# %%
map1
# map1.save(outfile="Vaccrate.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e415a0889d2134ddf366316cf130dad1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e415a0889d2134ddf366316cf130dad1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e415a0889d2134ddf366316cf130dad1 = L.map(
#                 &quot;map_e415a0889d2134ddf366316cf130dad1&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecffac2d6d75b3bcce49db8ba74fc61e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e415a0889d2134ddf366316cf130dad1);
#
#
#             var choropleth_267f1d8c5e489d4e6b8c6ba86f01fee4 = L.featureGroup(
#                 {}
#             ).addTo(map_e415a0889d2134ddf366316cf130dad1);
#
#
#         function geo_json_6f57402a3011dd0ef12a449d7a572cb4_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AK&quot;: case &quot;AR&quot;: case &quot;MT&quot;: case &quot;ND&quot;: case &quot;OK&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;NJ&quot;: case &quot;NY&quot;: case &quot;RI&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CO&quot;: case &quot;HI&quot;: case &quot;IL&quot;: case &quot;ME&quot;: case &quot;MN&quot;: case &quot;NH&quot;: case &quot;OR&quot;: case &quot;PA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;: case &quot;GA&quot;: case &quot;MI&quot;: case &quot;NV&quot;: case &quot;NM&quot;: case &quot;NC&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;WV&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6f57402a3011dd0ef12a449d7a572cb4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6f57402a3011dd0ef12a449d7a572cb4 = L.geoJson(null, {
#                 onEachFeature: geo_json_6f57402a3011dd0ef12a449d7a572cb4_onEachFeature,
#
#                 style: geo_json_6f57402a3011dd0ef12a449d7a572cb4_styler,
#         });
#
#         function geo_json_6f57402a3011dd0ef12a449d7a572cb4_add (data) {
#             geo_json_6f57402a3011dd0ef12a449d7a572cb4
#                 .addData(data)
#                 .addTo(choropleth_267f1d8c5e489d4e6b8c6ba86f01fee4);
#         }
#             geo_json_6f57402a3011dd0ef12a449d7a572cb4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot

# %%
map2
# map2.save(outfile="Boostrate.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b983b396ff72d653e98f0b3fd2962197 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b983b396ff72d653e98f0b3fd2962197&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b983b396ff72d653e98f0b3fd2962197 = L.map(
#                 &quot;map_b983b396ff72d653e98f0b3fd2962197&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd6d84932fa62f7737b217fd55fd1e58 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b983b396ff72d653e98f0b3fd2962197);
#
#
#             var choropleth_1578aa273aa297836a922ea930bd0a44 = L.featureGroup(
#                 {}
#             ).addTo(map_b983b396ff72d653e98f0b3fd2962197);
#
#
#         function geo_json_ef3d5e7b9b33a58f5ad97934aaaad232_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;ID&quot;: case &quot;LA&quot;: case &quot;MS&quot;: case &quot;TN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;: case &quot;AZ&quot;: case &quot;IL&quot;: case &quot;IA&quot;: case &quot;MI&quot;: case &quot;NC&quot;: case &quot;RI&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AR&quot;: case &quot;KY&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;SC&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;WV&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NM&quot;: case &quot;VT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IN&quot;: case &quot;KS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;OH&quot;: case &quot;SD&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ef3d5e7b9b33a58f5ad97934aaaad232_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ef3d5e7b9b33a58f5ad97934aaaad232 = L.geoJson(null, {
#                 onEachFeature: geo_json_ef3d5e7b9b33a58f5ad97934aaaad232_onEachFeature,
#
#                 style: geo_json_ef3d5e7b9b33a58f5ad97934aaaad232_styler,
#         });
#
#         function geo_json_ef3d5e7b9b33a58f5ad97934aaaad232_add (data) {
#             geo_json_ef3d5e7b9b33a58f5ad97934aaaad232
#                 .addData(data)
#                 .addTo(choropleth_1578aa273aa297836a922ea930bd0a44);
#         }
#             geo_json_ef3d5e7b9b33a58f5ad97934aaaad232_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 5

# %%
map3
# map3.save(outfile="Vaccboostdiff.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3c10cbb799d3b7d733769c385194fcd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3c10cbb799d3b7d733769c385194fcd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b3c10cbb799d3b7d733769c385194fcd = L.map(
#                 &quot;map_b3c10cbb799d3b7d733769c385194fcd&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83e2484d8180382edff2d952961dfe20 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b3c10cbb799d3b7d733769c385194fcd);
#
#
#             var choropleth_1a4dd11da4e2ecc8ff436bc7539545f5 = L.featureGroup(
#                 {}
#             ).addTo(map_b3c10cbb799d3b7d733769c385194fcd);
#
#
#         function geo_json_4afe914b1d9e01457259dbfd74644677_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;FL&quot;: case &quot;KY&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;TX&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;: case &quot;NM&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;IA&quot;: case &quot;MN&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;OR&quot;: case &quot;VT&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CO&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;NE&quot;: case &quot;PA&quot;: case &quot;SD&quot;: case &quot;WA&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;LA&quot;: case &quot;MS&quot;: case &quot;TN&quot;: case &quot;UT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4afe914b1d9e01457259dbfd74644677_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4afe914b1d9e01457259dbfd74644677 = L.geoJson(null, {
#                 onEachFeature: geo_json_4afe914b1d9e01457259dbfd74644677_onEachFeature,
#
#                 style: geo_json_4afe914b1d9e01457259dbfd74644677_styler,
#         });
#
#         function geo_json_4afe914b1d9e01457259dbfd74644677_add (data) {
#             geo_json_4afe914b1d9e01457259dbfd74644677
#                 .addData(data)
#                 .addTo(choropleth_1a4dd11da4e2ecc8ff436bc7539545f5);
#         }
#             geo_json_4afe914b1d9e01457259dbfd74644677_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.5691

# %% [markdown]
# ### Cleaning Code for State Booster Reasons
#
# * 4 seperate segments were used for each state, with similar practices to the cleaning done for the maps

# %%
i = 0
cur_state = pulse[(pulse['EST_ST']==22)]
cur_state.reset_index(inplace = True)
data = {'State': [], 'Reason': []}
noboostLA = pd.DataFrame(data=data)

while(i < len(cur_state)):
    j = 1
    while(j < 10):
        if(cur_state.loc[i, f"WHYNOBSTR{j}"] == 1):
            noboostLA = noboostLA.append({'State': "LA", 'Reason': j}, ignore_index=True)
        j += 1
    i += 1
    
i = 0
cur_state = pulse[(pulse['EST_ST']==28)]
cur_state.reset_index(inplace = True)
data = {'State': [], 'Reason': []}
noboostMS = pd.DataFrame(data=data)

while(i < len(cur_state)):
    j = 1
    while(j < 10):
        if(cur_state.loc[i, f"WHYNOBSTR{j}"] == 1):
            noboostMS = noboostMS.append({'State': "LA", 'Reason': j}, ignore_index=True)
        j += 1
    i += 1
    
i = 0
cur_state = pulse[(pulse['EST_ST']==47)]
cur_state.reset_index(inplace = True)
data = {'State': [], 'Reason': []}
noboostTN = pd.DataFrame(data=data)

while(i < len(cur_state)):
    j = 1
    while(j < 10):
        if(cur_state.loc[i, f"WHYNOBSTR{j}"] == 1):
            noboostTN = noboostTN.append({'State': "LA", 'Reason': j}, ignore_index=True)
        j += 1
    i += 1
    
i = 0
cur_state = pulse[(pulse['EST_ST']==49)]
cur_state.reset_index(inplace = True)
data = {'State': [], 'Reason': []}
noboostUT = pd.DataFrame(data=data)

while(i < len(cur_state)):
    j = 1
    while(j < 10):
        if(cur_state.loc[i, f"WHYNOBSTR{j}"] == 1):
            noboostUT = noboostUT.append({'State': "LA", 'Reason': j}, ignore_index=True)
        j += 1
    i += 1

# %% [markdown]
# ### Reason Graphs
#
# * 4 graphs were created for the states and 1 for the overall

# %%
noboostLA["Reason"].value_counts().plot(kind="bar", title = "Louisiana", xlabel = "Reason", ylabel = "Num Responses")
# Out:
# <AxesSubplot:title={'center':'Louisiana'}, xlabel='Reason', ylabel='Num Responses'>

# %%
noboostMS["Reason"].value_counts().plot(kind="bar", title = "Mississippi", xlabel = "Reason", ylabel = "Num Responses")
# Out:
# <AxesSubplot:title={'center':'Mississippi'}, xlabel='Reason', ylabel='Num Responses'>

# %%
noboostTN["Reason"].value_counts().plot(kind="bar", title = "Tennessee", xlabel = "Reason", ylabel = "Num Responses")
# Out:
# <AxesSubplot:title={'center':'Tennessee'}, xlabel='Reason', ylabel='Num Responses'>

# %%
noboostUT["Reason"].value_counts().plot(kind="bar", title = "Utah", xlabel = "Reason", ylabel = "Num Responses")
# Out:
# <AxesSubplot:title={'center':'Utah'}, xlabel='Reason', ylabel='Num Responses'>

# %%
noboostOVR = pd.concat([noboostLA, noboostMS, noboostTN, noboostUT])
noboostOVR["Reason"].value_counts().plot(kind="bar", title = "Overall", xlabel = "Reason", ylabel = "Num Responses")
# Out:
# <AxesSubplot:title={'center':'Overall'}, xlabel='Reason', ylabel='Num Responses'>

# %% [markdown]
# Value counts for easier interpretations

# %%
noboostOVR["Reason"].value_counts()
# Out:
# 3.0    340
# 5.0    299
# 2.0    276
# 6.0    162
# 7.0    136
# 9.0     96
# 4.0     74
# 1.0     39
# 8.0      9
# Name: Reason, dtype: int64
