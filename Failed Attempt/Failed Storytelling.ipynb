# %%
import pandas as pd
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

pulse = pd.read_csv("pulse2022_puf_46.csv")

# %%
pulse["Total Food"] = pulse["TSPNDFOOD"] + pulse["TSPNDPRPD"]

# %%
pulse["Total Food"].head()
# Out:
# 0    300
# 1    125
# 2    400
# 3    490
# 4     65
# Name: Total Food, dtype: int64

# %%
data_to_plot = pulse[pulse["CURFOODSUF"] > 0]

# %%
sns.catplot(x="CURFOODSUF", y="Total Food", kind="box", data=data_to_plot)

# %%
sns.catplot(x="LIVQTRRV", y="Total Food", kind="box", data=pulse)
